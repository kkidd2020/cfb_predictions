# %%
import pandas as pd
import numpy as np
from __future__ import print_function
import time
import cfbd
from cfbd.rest import ApiException
from pprint import pprint
import pandas as pd
from pandas.io.json import json_normalize
import json
import numpy as np
from datetime import datetime

# %%
# Configure API key authorization: ApiKeyAuth
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = 'RRRpRRQDqVoLX6S9Oivl7G9fXmZ/4TDcL9q+xg6pBW+yWfU1PIrYm/cbwKVuIfwn'
configuration.api_key_prefix['Authorization'] = 'Bearer'

# %%
#Week 1

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=1)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w1 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 2

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=2)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w2 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 3

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=3)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w3 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 4

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=4)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w4 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 5

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=5)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w5 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 6

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=6)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w6 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 7

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=7)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w7 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 8

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=8)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w8 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 9

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=9)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w9 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 10

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=10)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w10 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 11

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=11)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w11 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 12

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2021,week=12)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w12 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
game_stats_df_2021 = pd.concat([game_stats_w1,game_stats_w2,game_stats_w3,game_stats_w4,game_stats_w5,game_stats_w6,game_stats_w7,game_stats_w8,game_stats_w9,game_stats_w10,game_stats_w11,game_stats_w12],axis=0)

# %%
game_stats_df_2021.head()
# Out:
#           id         school             stat value
# 0  401282614  Florida State       rushingTDs     3
# 1  401282614  Florida State       passingTDs     2
# 2  401282614  Florida State  kickReturnYards    72
# 3  401282614  Florida State    kickReturnTDs     0
# 4  401282614  Florida State      kickReturns     3

# %%
game_stats_df_pivot = pd.pivot_table(data=game_stats_df_2021,index=['id','school'],columns='stat',values='value',aggfunc='first')
game_stats_2021 = game_stats_df_pivot.reset_index(drop=False)

# %%
game_stats_2021[game_stats_2021['school']=='Michigan']
# Out:
# stat         id    school completionAttempts defensiveTDs firstDowns  \
# 623   401282727  Michigan              15-28            0         19
# 663   401282770  Michigan              29-40            2         24
# 666   401282772  Michigan              13-17            0         22
# 668   401282773  Michigan               7-15            0         20
# 670   401282774  Michigan              12-17            0         28
# 672   401282775  Michigan               9-16            0         15
# 674   401282776  Michigan              18-30            0         15
# 676   401282777  Michigan              31-48            0         26
# 678   401282778  Michigan              22-39            0         26
# 680   401282779  Michigan              23-32            0         28
# 682   401282780  Michigan              19-29            0         21
#
# stat fourthDownEff fumblesLost fumblesRecovered interceptionTDs  \
# 623            1-1           0                1             NaN
# ...

# %%
game_stats_2021.to_csv('game_stats_2021.csv')
