# %%
import pandas as pd
import numpy as np
from __future__ import print_function
import time
import cfbd
from cfbd.rest import ApiException
from pprint import pprint
import pandas as pd
from pandas.io.json import json_normalize
import json
import numpy as np
from datetime import datetime

# %%
# Configure API key authorization: ApiKeyAuth
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = 'RRRpRRQDqVoLX6S9Oivl7G9fXmZ/4TDcL9q+xg6pBW+yWfU1PIrYm/cbwKVuIfwn'
configuration.api_key_prefix['Authorization'] = 'Bearer'

# %%
#Week 1

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=1)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w1 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 2

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=2)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w2 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 3

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=3)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w3 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 4

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=4)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w4 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 5

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=5)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w5 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 6

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=6)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w6 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 7

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=7)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w7 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 8

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=8)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w8 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 9

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=9)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w9 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 10

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=10)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w10 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 11

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=11)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w11 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
#Week 12

# %%
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
games = api_instance.get_team_game_stats(year=2022,week=12)
game_stats_df = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[0].school,stat=s.category,value=s.stat) for g in games for s in g.teams[0].stats])
game_stats_df1 = pd.DataFrame.from_records([dict(id = g.id,school=g.teams[1].school,stat=s.category,value=s.stat) for g in games for s in g.teams[1].stats])
game_stats_w12 = pd.concat([game_stats_df,game_stats_df1],axis=0)

# %%
game_stats_df_2022 = pd.concat([game_stats_w1,game_stats_w2,game_stats_w3,game_stats_w4,game_stats_w5,game_stats_w6,game_stats_w7,game_stats_w8,game_stats_w9,game_stats_w10,game_stats_w11,game_stats_w12],axis=0)

# %%
game_stats_df_pivot = pd.pivot_table(data=game_stats_df_2022,index=['id','school'],columns='stat',values='value',aggfunc='first')
game_stats_2022 = game_stats_df_pivot.reset_index(drop=False)

# %%
game_stats_2022[game_stats_2022['school']=='Michigan']
# Out:
# stat         id    school completionAttempts defensiveTDs firstDowns  \
# 519   401404149  Michigan              21-26            1         26
# 567   401405067  Michigan              18-28            1         25
# 583   401405077  Michigan              17-22            0         23
# 617   401405097  Michigan              18-26            0         22
# 623   401405100  Michigan              18-24            0         24
# 639   401405108  Michigan              28-36            0         26
# 652   401405115  Michigan              17-24            0         28
# 672   401405125  Michigan              15-26            0         27
# 688   401405133  Michigan              13-27            1         22
# 696   401405137  Michigan              10-20            1         27
# 713   401405145  Michigan              18-34            0         18
#
# stat fourthDownEff fumblesLost fumblesRecovered interceptionTDs  \
# 519            0-0           0                1             NaN
# 567            2-2           0                2               0
# 583            0-0           0                0             NaN
# 617            1-1           1                1               0
# 623            1-1           0                0             NaN
# 639            0-1           0                0               0
# 652            1-1           0                0             NaN
# 672            1-1           1                0               0
# 688            3-3           0                0               1
# 696            2-2           0                0             NaN
# 713            3-4           1                0             NaN
#
# stat interceptionYards  ... sacks tackles tacklesForLoss thirdDownEff  \
# 519                NaN  ...     0      26              5         9-13
# 567                 37  ...     7      40             11         3-10
# 583                NaN  ...     1      33              2          2-6
# 617                  0  ...     3      38              5         5-12
# 623                NaN  ...     4      34              6         4-11
# 639                  0  ...     7      40             10         7-14
# 652                NaN  ...     2      20              4        11-17
# 672                 34  ...     2      26              7         9-16
# 688                 81  ...     3      25              7         7-17
# 696                NaN  ...     2      27              2         4-10
# 713                NaN  ...     0      39              1         7-19
#
# stat totalFumbles totalPenaltiesYards totalYards turnovers yardsPerPass  \
# 519             0                4-24        465         0         10.5
# 567             0                1-10        440         0          7.4
# 583             1                3-35        588         1         14.5
# 617             3                1-15        463         1          8.5
# 623             1                5-50        327         0          6.5
# 639             1               10-85        469         1          8.4
# 652             2                9-61        563         1          6.0
# 672             1                4-25        443         1          6.4
# 688           NaN                3-20        433         0          5.6
# 696             1                1-15        412         0          7.4
# 713             2                4-25        376         1          6.1
#
# stat yardsPerRushAttempt
# 519                  4.5
# 567                  5.9
# 583                  8.1
# 617                  6.1
# 623                  4.1
# 639                  4.1
# 652                  7.6
# 672                  5.3
# 688                  5.3
# 696                  5.4
# 713                  4.2
#
# [11 rows x 37 columns]

# %%
game_stats_2022.dtypes
# Out:
# stat
# id                      int64
# school                 object
# completionAttempts     object
# defensiveTDs           object
# firstDowns             object
# fourthDownEff          object
# fumblesLost            object
# fumblesRecovered       object
# interceptionTDs        object
# interceptionYards      object
# interceptions          object
# kickReturnTDs          object
# kickReturnYards        object
# kickReturns            object
# kickingPoints          object
# netPassingYards        object
# passesDeflected        object
# passesIntercepted      object
# passingTDs             object
# possessionTime         object
# puntReturnTDs          object
# puntReturnYards        object
# puntReturns            object
# qbHurries              object
# rushingAttempts        object
# rushingTDs             object
# rushingYards           object
# sacks                  object
# tackles                object
# tacklesForLoss         object
# thirdDownEff           object
# totalFumbles           object
# totalPenaltiesYards    object
# totalYards             object
# turnovers              object
# yardsPerPass           object
# yardsPerRushAttempt    object
# dtype: object

# %%
game_stats_2022.to_csv('game_stats_2022.csv')
