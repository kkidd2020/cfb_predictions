# %%
import pandas as pd
import numpy as np
import requests
import cfbd

# %%
from __future__ import print_function
import time
import cfbd
from cfbd.rest import ApiException
from pprint import pprint

# Configure API key authorization: ApiKeyAuth
configuration = cfbd.Configuration()
configuration.api_key['Authorization'] = 'RRRpRRQDqVoLX6S9Oivl7G9fXmZ/4TDcL9q+xg6pBW+yWfU1PIrYm/cbwKVuIfwn'
configuration.api_key_prefix['Authorization'] = 'Bearer'

# create an instance of the API class
api_instance = cfbd.GamesApi(cfbd.ApiClient(configuration))
try:
    # Betting lines
    games = api_instance.get_games(year=2015,team='Michigan')
    pprint(games)
except ApiException as e:
    print("Exception when calling BettingApi->get_lines: %s\n" % e)
# Out:
# [{'attendance': 47825,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 130,
#  'away_line_scores': [0, 3, 7, 7],
#  'away_points': 17,
#  'away_post_win_prob': 0.09824754911149114,
#  'away_postgame_elo': 1546,
#  'away_pregame_elo': 1553,
#  'away_team': 'Michigan',
#  'conference_game': False,
#  'excitement_index': 4.6176711164,
#  'highlights': None,
#  'home_conference': 'Pac-12',
#  'home_division': 'fbs',
#  'home_id': 254,
#  'home_line_scores': [3, 7, 7, 7],
#  'home_points': 24,
#  'home_post_win_prob': 0.9017524508885089,
#  'home_postgame_elo': 1610,
#  'home_pregame_elo': 1603,
#  'home_team': 'Utah',
#  'id': 400756883,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-09-04T00:30:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Rice-Eccles Stadium',
#  'venue_id': 587,
#  'week': 1},
#  {'attendance': 109651,
#  'away_conference': 'Pac-12',
#  'away_division': 'fbs',
#  'away_id': 204,
#  'away_line_scores': [7, 0, 0, 0],
#  'away_points': 7,
#  'away_post_win_prob': 0.00022928818463718859,
#  'away_postgame_elo': 1396,
#  'away_pregame_elo': 1459,
#  'away_team': 'Oregon State',
#  'conference_game': False,
#  'excitement_index': 3.56509965119999,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [3, 14, 3, 15],
#  'home_points': 35,
#  'home_post_win_prob': 0.9997707118153628,
#  'home_postgame_elo': 1609,
#  'home_pregame_elo': 1546,
#  'home_team': 'Michigan',
#  'id': 400757019,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-09-12T16:00:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 2},
#  {'attendance': 108683,
#  'away_conference': 'Mountain West',
#  'away_division': 'fbs',
#  'away_id': 2439,
#  'away_line_scores': [0, 0, 0, 7],
#  'away_points': 7,
#  'away_post_win_prob': 0.0012792052694862166,
#  'away_postgame_elo': 1188,
#  'away_pregame_elo': 1198,
#  'away_team': 'UNLV',
#  'conference_game': False,
#  'excitement_index': 0.247736650199999,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [7, 14, 0, 7],
#  'home_points': 28,
#  'home_post_win_prob': 0.9987207947305138,
#  'home_postgame_elo': 1619,
#  'home_pregame_elo': 1609,
#  'home_team': 'Michigan',
#  'id': 400763511,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-09-19T16:00:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 3},
#  {'attendance': 108940,
#  'away_conference': 'FBS Independents',
#  'away_division': 'fbs',
#  'away_id': 252,
#  'away_line_scores': [0, 0, 0, 0],
#  'away_points': 0,
#  'away_post_win_prob': 1.2634280427303857e-05,
#  'away_postgame_elo': 1534,
#  'away_pregame_elo': 1618,
#  'away_team': 'BYU',
#  'conference_game': False,
#  'excitement_index': 1.81035507409999,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [7, 24, 0, 0],
#  'home_points': 31,
#  'home_post_win_prob': 0.9999873657195727,
#  'home_postgame_elo': 1703,
#  'home_pregame_elo': 1619,
#  'home_team': 'Michigan',
#  'id': 400763519,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-09-26T16:00:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 4},
#  {'attendance': 51802,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 130,
#  'away_line_scores': [0, 6, 15, 7],
#  'away_points': 28,
#  'away_post_win_prob': 0.9965433365865064,
#  'away_postgame_elo': 1741,
#  'away_pregame_elo': 1703,
#  'away_team': 'Michigan',
#  'conference_game': True,
#  'excitement_index': 3.3616752942,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 120,
#  'home_line_scores': [0, 0, 0, 0],
#  'home_points': 0,
#  'home_post_win_prob': 0.003456663413493626,
#  'home_postgame_elo': 1340,
#  'home_pregame_elo': 1378,
#  'home_team': 'Maryland',
#  'id': 400763530,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-10-03T16:00:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Maryland Stadium',
#  'venue_id': 3665,
#  'week': 5},
#  {'attendance': 110452,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 77,
#  'away_line_scores': [0, 0, 0, 0],
#  'away_points': 0,
#  'away_post_win_prob': 1.415125438153364e-05,
#  'away_postgame_elo': 1533,
#  'away_pregame_elo': 1627,
#  'away_team': 'Northwestern',
#  'conference_game': True,
#  'excitement_index': 0.805903607199999,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [21, 7, 3, 7],
#  'home_points': 38,
#  'home_post_win_prob': 0.9999858487456185,
#  'home_postgame_elo': 1835,
#  'home_pregame_elo': 1741,
#  'home_team': 'Michigan',
#  'id': 400763535,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-10-10T19:30:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 6},
#  {'attendance': 111740,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 127,
#  'away_line_scores': [0, 7, 7, 13],
#  'away_points': 27,
#  'away_post_win_prob': 0.6432985394165089,
#  'away_postgame_elo': 1834,
#  'away_pregame_elo': 1827,
#  'away_team': 'Michigan State',
#  'conference_game': True,
#  'excitement_index': 8.37285859919999,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [0, 10, 10, 3],
#  'home_points': 23,
#  'home_post_win_prob': 0.3567014605834911,
#  'home_postgame_elo': 1828,
#  'home_pregame_elo': 1835,
#  'home_team': 'Michigan',
#  'id': 400763542,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-10-17T19:30:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 7},
#  {'attendance': 50709,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 130,
#  'away_line_scores': [7, 7, 7, 8],
#  'away_points': 29,
#  'away_post_win_prob': 0.5264343622449708,
#  'away_postgame_elo': 1817,
#  'away_pregame_elo': 1828,
#  'away_team': 'Michigan',
#  'conference_game': True,
#  'excitement_index': 8.4821006495,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 135,
#  'home_line_scores': [3, 13, 7, 3],
#  'home_points': 26,
#  'home_post_win_prob': 0.4735656377550293,
#  'home_postgame_elo': 1565,
#  'home_pregame_elo': 1554,
#  'home_team': 'Minnesota',
#  'id': 400763553,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-10-31T23:00:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'TCF Bank Stadium',
#  'venue_id': 3953,
#  'week': 9},
#  {'attendance': 109879,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 164,
#  'away_line_scores': [3, 13, 0, 0],
#  'away_points': 16,
#  'away_post_win_prob': 1.0367593678783926e-05,
#  'away_postgame_elo': 1305,
#  'away_pregame_elo': 1339,
#  'away_team': 'Rutgers',
#  'conference_game': True,
#  'excitement_index': 0.660158327999999,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [14, 21, 11, 3],
#  'home_points': 49,
#  'home_post_win_prob': 0.9999896324063212,
#  'home_postgame_elo': 1851,
#  'home_pregame_elo': 1817,
#  'home_team': 'Michigan',
#  'id': 400763559,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-11-07T20:30:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 10},
#  {'attendance': 49557,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 130,
#  'away_line_scores': [7, 17, 0, 10, 7, 7],
#  'away_points': 48,
#  'away_post_win_prob': 0.7145451168265005,
#  'away_postgame_elo': 1833,
#  'away_pregame_elo': 1851,
#  'away_team': 'Michigan',
#  'conference_game': True,
#  'excitement_index': 8.0822552742,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 84,
#  'home_line_scores': [6, 10, 10, 8, 7, 0],
#  'home_points': 41,
#  'home_post_win_prob': 0.2854548831734996,
#  'home_postgame_elo': 1432,
#  'home_pregame_elo': 1414,
#  'home_team': 'Indiana',
#  'id': 400763565,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-11-14T20:30:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Memorial Stadium',
#  'venue_id': 3830,
#  'week': 11},
#  {'attendance': 107418,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 130,
#  'away_line_scores': [7, 7, 7, 7],
#  'away_points': 28,
#  'away_post_win_prob': 0.9878818446864971,
#  'away_postgame_elo': 1846,
#  'away_pregame_elo': 1833,
#  'away_team': 'Michigan',
#  'conference_game': True,
#  'excitement_index': 4.6346752565,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 213,
#  'home_line_scores': [3, 7, 0, 6],
#  'home_points': 16,
#  'home_post_win_prob': 0.012118155313502932,
#  'home_postgame_elo': 1674,
#  'home_pregame_elo': 1687,
#  'home_team': 'Penn State',
#  'id': 400763574,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-11-21T17:00:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Beaver Stadium',
#  'venue_id': 3632,
#  'week': 12},
#  {'attendance': 111829,
#  'away_conference': 'Big Ten',
#  'away_division': 'fbs',
#  'away_id': 194,
#  'away_line_scores': [7, 7, 14, 14],
#  'away_points': 42,
#  'away_post_win_prob': 0.995911051616127,
#  'away_postgame_elo': 2107,
#  'away_pregame_elo': 2052,
#  'away_team': 'Ohio State',
#  'conference_game': True,
#  'excitement_index': 2.8441349819,
#  'highlights': None,
#  'home_conference': 'Big Ten',
#  'home_division': 'fbs',
#  'home_id': 130,
#  'home_line_scores': [0, 10, 0, 3],
#  'home_points': 13,
#  'home_post_win_prob': 0.0040889483838729875,
#  'home_postgame_elo': 1791,
#  'home_pregame_elo': 1846,
#  'home_team': 'Michigan',
#  'id': 400763578,
#  'neutral_site': False,
#  'notes': None,
#  'season': 2015,
#  'season_type': 'regular',
#  'start_date': '2015-11-28T17:00:00.000Z',
#  'start_time_tbd': None,
#  'venue': 'Michigan Stadium',
#  'venue_id': 3558,
#  'week': 13}]

# %%
df = pd.DataFrame(games)

# %%
type(games)
# Out:
# list
